# %%
import pandas as pd

# %%
ColNames=['Rank', 'Player', 'Pos', 'Year Inducted', 'From', 'To', '1st Team All-Pro', 'Number of Pro-Bowls', 'Years as Primary Starter',
 'CarAV', 'Games Played', 'PassingCmp', 'PassingAtt', 'PassingYds', 'PassingTD', 'PassLng',
 'PassingInt', 'Sk', 'Yds.1', 'RushingAtt', 'RushingYds', 'RushingTD', 'RushLng', 'ReceivingRec',
 'ReceivingYds', 'ReceivingTD', 'RecLong']

url = "https://www.pro-football-reference.com/hof/"
df = pd.read_html(url)
hof_df = df[0]
hof_df.columns = ColNames
hof_df.drop(columns = ['PassLng', 'Sk', 'Yds.1', 'RushLng', 'RecLong'])
hof_df['Hall of Fame'] = 'Y'
hof_df
# Out:
#      Rank             Player Pos  Year Inducted  From    To  1st Team All-Pro  \
# 0       1      Steve Atwater  DB           2020  1989  1999                 2
# 1       2        Isaac Bruce  WR           2020  1994  2009                 0
# 2       3  Harold Carmichael  WR           2020  1971  1984                 0
# 3       4       Jimbo Covert   T           2020  1983  1990                 2
# 4       5       Bobby Dillon  DB           2020  1952  1959                 4
# ..    ...                ...  ..            ...   ...   ...               ...
# 289   290        Cal Hubbard   T           1963  1927  1936                 4
# 290   291         Don Hutson   E           1963  1935  1945                 8
# 291   292    Bronko Nagurski  FB           1963  1930  1943                 4
# 292   293       Ernie Nevers  FB           1963  1926  1931                 5
# 293   294         Jim Thorpe  TB           1963  1920  1928                 1
#
# ...

# %%
hof_df.to_csv('hof.csv')
