# %%
# import dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn
import tensorflow as tf
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
# get data from database
Base = automap_base()
engine = create_engine('sqlite:///../data/fbdata.sqlite')
Base.metadata.create_all(engine)
Base.prepare(engine, reflect=True)
session = Session(engine)

# %%
csv = pd.read_csv('recentQBs.csv')
recentQBs_df = pd.DataFrame(csv)
recentQBs_df
# Out:
#     Unnamed: 0           Player  DraftYear  Rnd  Pick   Tm Pos   Age      To  \
# 0            0   Jameis Winston       2015    1     1  TAM  QB  21.0  2019.0
# 1            1   Marcus Mariota       2015    1     2  TEN  QB  21.0  2019.0
# 2            2  Garrett Grayson       2015    3    75  NOR  QB  24.0  2015.0
# 3            3     Sean Mannion       2015    3    89  STL  QB  23.0  2019.0
# 4            4      Bryce Petty       2015    4   103  NYJ  QB  24.0  2017.0
# ..         ...              ...        ...  ...   ...  ...  ..   ...     ...
# 60          60     James Morgan       2020    4   125  NYJ  QB  23.0     NaN
# 61          61       Jake Fromm       2020    5   167  BUF  QB   NaN     NaN
# 62          62       Jake Luton       2020    6   189  JAX  QB   NaN     NaN
# 63          63    Cole McDonald       2020    7   224  TEN  QB   NaN     NaN
# 64          64     Nate Stanley       2020    7   244  MIN  QB   NaN     NaN
#
#     AP1  ...  plays  rushAvg ydsFromScrimAvg  tdPerInt  compPct  ydsPerAtt  \
# 0     0  ...    145      2.0             2.0  2.321429     66.0        9.4
# 1     0  ...    339      6.6             6.7  7.500000     66.8        9.3
# 2     0  ...    215      1.3             1.5  2.370370     61.8        8.3
# 3     0  ...    133     -6.1            -6.0  1.537037     64.6        7.4
# 4     0  ...    192      1.8             1.8  6.200000     62.7        9.7
# ..  ...  ...    ...      ...             ...       ...      ...        ...
# 60    0  ...    130     -1.3            -1.3  1.911765     57.2        7.1
# 61    0  ...    134      0.3             0.3  4.333333     63.3        8.4
# 62    0  ...    116     -1.1            -1.1  2.866667     62.2        7.1
# 63    0  ...    251      3.5             3.5  2.916667     61.4        8.0
# 64    0  ...    161     -0.6            -0.7  2.956522     58.3        7.2
#
#     adjYdsPerAtt  effRate  success  predictedSuccess
# 0            9.4    163.3        1                 1
# 1           10.5    171.8        0                 0
# 2            8.3    145.3        0                 0
# 3            7.0    135.8        0                 0
# 4           10.6    166.0        0                 0
# ..           ...      ...      ...               ...
# 60           6.9    128.8        0                 0
# 61           9.1    156.2        0                 0
# 62           7.3    135.6        0                 0
# 63           8.3    146.8        0                 0
# 64           7.5    134.1        0                 0
#
# [65 rows x 34 columns]

# %%
# commit to sqlite database
recentQBs_df.to_sql('RecentQBs', con=engine, if_exists='replace', index=False)
